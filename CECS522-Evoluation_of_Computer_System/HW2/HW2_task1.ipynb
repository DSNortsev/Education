# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.linalg as la


def culculate_euclidean(data):
    count = 0
    for column_one, x1 in data:
        count += 1
        for column_two,x2 in data[count:]:
            print(f'{column_one},{column_two}: {x1},{x2}')
            print(np.sqrt((x2[0]-x1[0])**2 + (x2[1]-x1[1])**2))

# Create multi-dimentinal list
# data = np.array([[14, 13, 8, 6, 6, 4, 1],
#                 [2735, 253, 27, 27, 12, 91, 33]])

# columns = ['TKB','MAC','COBOL','BASIC','PASCAL', 'EDT', 'SOS']

# # Merge to tuples
# rows = list(zip(data[0],data[1]))
# # Add columns
# data_updated = list(zip(columns, rows))

# count = 0
# for column_one, x1 in data_updated:
#     count += 1
#     for column_two,x2 in data_updated[count:]:
#         print(f'{column_one},{column_two}: {x1},{x2}')
#         print(np.sqrt((x2[0]-x1[0])**2 + (x2[1]-x1[1])**2))
        
        
        
# # After merge COBAL and Basic
# data = np.array([[14, 13, 7, 6, 4, 1],
#                 [2735, 253, 27, 12, 91, 33]])

# columns = ['TKB','MAC','COBOL_BASIC','PASCAL', 'EDT', 'SOS']

# # Merge to tuples
# rows = list(zip(data[0],data[1]))
# # Add columns
# data_updated = list(zip(columns, rows))
# # culculate_euclidean(data_updated)




# # After merge COBAL and Basic
# data = np.array([[14, 13, 4.3, 4, 1],
#                 [2735, 253, 13, 91, 33]])

# columns = ['TKB','MAC','COBOL_BASIC_PASCAL', 'EDT', 'SOS']

# # Merge to tuples
# rows = list(zip(data[0],data[1]))
# # Add columns
# data_updated = list(zip(columns, rows))
# culculate_euclidean(data_updated)




# # After merge COBAL and Basic
# data = np.array([[14, 13, 4.3, 5],
#                 [2735, 253, 13, 62]])

# columns = ['TKB','MAC','COBOL_BASIC_PASCAL', 'EDT_SOS']

# # Merge to tuples
# rows = list(zip(data[0],data[1]))
# # Add columns
# data_updated = list(zip(columns, rows))
# culculate_euclidean(data_updated)


# import plotly.figure_factory as ff
# import numpy as np
# np.random.seed(1)

# # X = np.random.rand(15, 12) # 15 samples, with 12 dimensions each
# print(X)
# fig = ff.create_dendrogram(X[0:3])
# fig.update_layout(width=800, height=500)
# fig.show()

# data = np.array([[14, 2.5],
#                 [2735, 26.4]])

# columns = ['TKB','MAC_COBOL_BASIC_PASCAL_EDT_SOS']

# # Merge to tuples
# rows = list(zip(data[0],data[1]))
# # Add columns
# data_updated = list(zip(columns, rows))
# culculate_euclidean(data_updated)

# X = np.array([[14,2735], [13,253], [8,27], [6,27],[6,12], [4,91], [1,33],[14,2735],[13,253],[7,27],[6,12],[4,91],
#               [1,33],[14,2735],[13,253],[4.3,13], [4,91],[1,33],[14,2735],[3,253],[4.3,13],[5,62],[14,2735],
#              [13,253], [1.86,25.4], [14,2735], [2.5, 46.4],[2.4, 397] ])
# fig = ff.create_dendrogram(X)
# fig.update_layout(width=800, height=500)
# fig.show()

from scipy.cluster.hierarchy import dendrogram, linkage
from matplotlib import pyplot as plt

# # create some data with four clusters
# X, y = make_blobs(200, centers=4, random_state=42)
data = np.array([[14, 13, 8, 6, 6, 4, 1],
                [2735, 253, 27, 27, 12, 91, 33]])

columns = ['TKB','MAC','COBOL_BASIC','PASCAL', 'EDT', 'SOS']
Z = linkage(X, 'single')
fig = plt.figure(figsize=(20, 10))
dn = dendrogram(Z)
plt.show()
# plot the results
# plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='rainbow');
