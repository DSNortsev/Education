# %% [markdown]
# # Merge Sort
#
# **Merge Sort** is a Divide and Conquer algorithm. It divides input array in two halves, calls itself for the two halves and then merges the two sorted halves. The merge() function is used for merging two halves. The merge(arr, l, m, r) is key process that assumes that arr[l..m] and arr[m+1..r] are sorted and merges the two sorted sub-arrays into one. See following C implementation for details.

# %%
def mergeSort(myList):
    print(f'Initial array: {myList}')
    if len(myList) > 1:
        mid = len(myList) // 2
        print(f'Find a middle point: {mid}')
        left = myList[:mid]
        right = myList[mid:]
        print(f'Divide in left: {left} and right: {right}')
        # Recursive call on each half
        mergeSort(left)
        mergeSort(right)

        # Two iterators for traversing the two halves
        i = 0
        j = 0
        
        # Iterator for the main list
        k = 0
        
        while i < len(left) and j < len(right):
            print(f'Before: {myList}, {left}, {right}')
            if left[i] < right[j]:
              # The value from the left half has been used
              myList[k] = left[i]
              # Move the iterator forward
              i += 1
            else:
                myList[k] = right[j]
                j += 1
            # Move to the next slot
            k += 1
        print(f'After: {myList}')   

        # For all the remaining values
        print(f'Left side: {left[i:]}')
        while i < len(left):
            myList[k] = left[i]
            i += 1
            k += 1
        print(f'Add remaining from left side: {myList}')
        
        print(f'Right side: {right[j:]}\n')
        while j < len(right):
            myList[k]=right[j]
            j += 1
            k += 1
            print(f'Add remaining from right side: {myList}')
        print(f'Final array: {myList}')

myList = [54,26,93,17,77,31,44,55,20]
mergeSort(myList)
print(myList)
# Out:
# Initial array: [54, 26, 93, 17, 77, 31, 44, 55, 20]
# Find a middle point: 4
# Divide in left: [54, 26, 93, 17] and right: [77, 31, 44, 55, 20]
# Initial array: [54, 26, 93, 17]
# Find a middle point: 2
# Divide in left: [54, 26] and right: [93, 17]
# Initial array: [54, 26]
# Find a middle point: 1
# Divide in left: [54] and right: [26]
# Initial array: [54]
# Initial array: [26]
# Before: [54, 26], [54], [26]
# After: [26, 26]
# Left side: [54]
# Add remaining from left side: [26, 54]
# Right side: []
#
# Final array: [26, 54]
# Initial array: [93, 17]
# Find a middle point: 1
# Divide in left: [93] and right: [17]
# Initial array: [93]
# Initial array: [17]
# Before: [93, 17], [93], [17]
# After: [17, 17]
# Left side: [93]
# Add remaining from left side: [17, 93]
# Right side: []
#
# Final array: [17, 93]
# Before: [54, 26, 93, 17], [26, 54], [17, 93]
# Before: [17, 26, 93, 17], [26, 54], [17, 93]
# Before: [17, 26, 93, 17], [26, 54], [17, 93]
# After: [17, 26, 54, 17]
# ...
